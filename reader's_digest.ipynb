# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Define URL to scrape and create Soup object to parse HTML
url = "https://www.rd.com/list/hit-movies-that-were-books-first/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
main_area = soup.find("section", class_="content-wrapper pure-g")
books = main_area.find_all('div', class_='listicle-card')

# %%
# create an empty list to store the book titles and authors
book_list = []

# %%
# loop through each section element and extract the book titles and authors
for book in books:
    # find the "h2" elements within the book section
    h2_tags = book.find_all('h2')
    
    # find the index of the "h2" element you need
    index = None
    for i, h2 in enumerate(h2_tags):
        if 'by' in h2.get_text():
            index = i
            break
    
    # skip this book if the desired "h2" element was not found
    if index is None:
        continue
    
    # get the title and author string from the desired "h2" element
    title_author_str = h2_tags[index].get_text().strip()

    try:
        # extract the title and author name from the title_author string
        title, separator, author = title_author_str.partition(' by ')

        # get the book published and movie released years
        book_published = ""
        movie_released = ""
        for p in book.find_all('p'):
            strong_tag = p.find('strong')
            if strong_tag:
                strong_text = strong_tag.get_text().strip()
                if strong_text == "Book published:":
                    book_published = p.get_text().replace(strong_text, '').strip()
                elif strong_text == "Movie released:":
                    movie_released = p.get_text().replace(strong_text, '').strip()

        # create a dictionary for the book
        summary_dict = {
            "Title": title,
            "Author": author,
            "Book Published": book_published,
            "Movie Released": movie_released
        }

        # add the book dictionary to the book list
        book_list.append(summary_dict)
    
    except ValueError:
        # if there was an error extracting the title and author, skip this book
        print(f"Skipping book with title and author string: {title_author_str}")
        continue

# %%
browser.quit()

# %%
# Convert book movie data to DataFrame
df = pd.DataFrame(book_list)

# %%
# remove the number from the beginning of the "Title" column
df['Title'] = df["Title"].str.replace(r'^\d+\.\s+', '')
df
# Out:
# C:\Users\kathe\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                 Title               Author  \
# 0                        The Invention of Hugo Cabret       Brian Selznick
# 1                                      My Abandonment           Peter Rock
# 2                                            The Help     Kathryn Stockett
# 3                               The Cider House Rules          John Irving
# 4                                   David Copperfield      Charles Dickens
# 5                   Charlie and the Chocolate Factory           Roald Dahl
# 6                     One Flew Over The Cuckoo’s Nest            Ken Kesey
# 7   The Orchid Thief: A True Story of Beauty and O...         Susan Orlean
# 8                                       Jurassic Park     Michael Crichton
# 9                                     The Hate U Give         Angie Thomas
# 10                                               Dune        Frank Herbert
# 11                                        The Shining         Stephen King
# 12                                      High Fidelity          Nick Hornby
# 13                       The Lord of the Rings series       J.R.R. Tolkien
# 14                           The Chronicles of Narnia           C.S. Lewis
# 15                         If Beale Street Could Talk        James Baldwin
# 16                                      The Godfather           Mario Puzo
# 17                                   The Glass Castle      Jeannette Walls
# 18                              To Kill a Mockingbird           Harper Lee
# 19  The Princess Bride: S. Morgenstern’s Classic T...      William Goldman
# 20  Wild: From Lost to Found on the Pacific Crest ...       Cheryl Strayed
# 21                                          Atonement           Ian McEwan
# 22                                         Life of Pi          Yann Martel
# 23                                               Push             Sapphire
# 24                                   12 Years A Slave      Solomon Northup
# 25                                Pride and Prejudice          Jane Austen
# 26                                         Fight Club      Chuck Palahniuk
# 27                                  Crazy Rich Asians           Kevin Kwan
# 28                               Call Me By Your Name         André Aciman
# 29                         The Picture of Dorian Gray          Oscar Wilde
# 30                                      Anna Karenina          Leo Tolstoy
# 31                                 Brokeback Mountain         Annie Proulx
# 32                                   The Color Purple         Alice Walker
# 33                                            The BFG           Roald Dahl
# 34                                   The Great Gatsby  F. Scott Fitzgerald
# 35                                          The Hours   Michael Cunningham
# 36                                 Revolutionary Road        Richard Yates
# 37                    The Lost Child of Philomena Lee      Martin Sixsmith
# 38                   Alice’s Adventures in Wonderland        Lewis Carroll
# 39                                       Little Women     Louisa M. Alcott
#
#    Book Published Movie Released
# 0            2007           2011
# 1            2009           2018
# 2            2009           2011
# 3            1985           1999
# 4            1850           2019
# 5            1964
# 6            1963           1975
# 7            1998           2002
# 8            1990           1993
# 9            2017           2018
# 10           1965
# 11           1977           1980
# 12           1995           2000
# 13
# 14
# 15           1974           2018
# 16           1969
# 17           2005           2017
# 18           1960           1962
# 19           1973           1987
# 20           2012           2014
# 21           2003           2007
# 22           2001           2012
# 23           1996           2009
# 24           1853           2013
# 25           1813  1995 and 2005
# 26           1996           1999
# 27           2013           2018
# 28           2007           2017
# 29           1891  1945 and 2009
# 30           1878           2012
# 31           1997           2005
# 32           1982           1985
# 33           1982           2016
# 34           1925           2013
# 35           1998           2002
# 36           1961           2008
# 37           1955           2013
# 38           1865           2010
# 39      1868–1869           2019

# %%
# check for rows with more than one movie release year
mult = df['Movie Released'].str.count('\d{4}') >1
rows_with_two_years = df[mult].copy()
rows_with_two_years
# Out:
#                          Title       Author Book Published Movie Released
# 25         Pride and Prejudice  Jane Austen           1813  1995 and 2005
# 29  The Picture of Dorian Gray  Oscar Wilde           1891  1945 and 2009

# %%
# split rows with two movie release years into two separate rows
if not rows_with_two_years.empty:
    new_rows = []
    for _, row in rows_with_two_years.iterrows():
        years = row['Movie Released'].split()
        for year in years:
            new_row = row.copy()
            new_row['Movie Released'] = year
            new_rows.append(new_row)
    
    # join together the dataframes
    df = pd.concat([df, pd.DataFrame(new_rows)])
    
    # Reset the index
    df.reset_index(drop=True, inplace=True)
    
    # drop the original rows with multiple movie release years
    df.drop(rows_with_two_years.index, inplace=True)
    
# reset the index
df.reset_index(drop=True, inplace=True)
    
df
# Out:
#                                                 Title               Author  \
# 0                        The Invention of Hugo Cabret       Brian Selznick
# 1                                      My Abandonment           Peter Rock
# 2                                            The Help     Kathryn Stockett
# 3                               The Cider House Rules          John Irving
# 4                                   David Copperfield      Charles Dickens
# 5                   Charlie and the Chocolate Factory           Roald Dahl
# 6                     One Flew Over The Cuckoo’s Nest            Ken Kesey
# 7   The Orchid Thief: A True Story of Beauty and O...         Susan Orlean
# 8                                       Jurassic Park     Michael Crichton
# 9                                     The Hate U Give         Angie Thomas
# 10                                               Dune        Frank Herbert
# 11                                        The Shining         Stephen King
# 12                                      High Fidelity          Nick Hornby
# 13                       The Lord of the Rings series       J.R.R. Tolkien
# 14                           The Chronicles of Narnia           C.S. Lewis
# 15                         If Beale Street Could Talk        James Baldwin
# 16                                      The Godfather           Mario Puzo
# 17                                   The Glass Castle      Jeannette Walls
# 18                              To Kill a Mockingbird           Harper Lee
# 19  The Princess Bride: S. Morgenstern’s Classic T...      William Goldman
# 20  Wild: From Lost to Found on the Pacific Crest ...       Cheryl Strayed
# 21                                          Atonement           Ian McEwan
# 22                                         Life of Pi          Yann Martel
# 23                                               Push             Sapphire
# 24                                   12 Years A Slave      Solomon Northup
# 25                                         Fight Club      Chuck Palahniuk
# 26                                  Crazy Rich Asians           Kevin Kwan
# 27                               Call Me By Your Name         André Aciman
# 28                                      Anna Karenina          Leo Tolstoy
# 29                                 Brokeback Mountain         Annie Proulx
# 30                                   The Color Purple         Alice Walker
# 31                                            The BFG           Roald Dahl
# 32                                   The Great Gatsby  F. Scott Fitzgerald
# 33                                          The Hours   Michael Cunningham
# 34                                 Revolutionary Road        Richard Yates
# 35                    The Lost Child of Philomena Lee      Martin Sixsmith
# 36                   Alice’s Adventures in Wonderland        Lewis Carroll
# 37                                       Little Women     Louisa M. Alcott
# 38                                Pride and Prejudice          Jane Austen
# 39                                Pride and Prejudice          Jane Austen
# 40                                Pride and Prejudice          Jane Austen
# 41                         The Picture of Dorian Gray          Oscar Wilde
# 42                         The Picture of Dorian Gray          Oscar Wilde
# 43                         The Picture of Dorian Gray          Oscar Wilde
#
#    Book Published Movie Released
# 0            2007           2011
# 1            2009           2018
# 2            2009           2011
# 3            1985           1999
# 4            1850           2019
# 5            1964
# 6            1963           1975
# 7            1998           2002
# 8            1990           1993
# 9            2017           2018
# 10           1965
# 11           1977           1980
# 12           1995           2000
# 13
# 14
# 15           1974           2018
# 16           1969
# 17           2005           2017
# 18           1960           1962
# 19           1973           1987
# 20           2012           2014
# 21           2003           2007
# 22           2001           2012
# 23           1996           2009
# 24           1853           2013
# 25           1996           1999
# 26           2013           2018
# 27           2007           2017
# 28           1878           2012
# 29           1997           2005
# 30           1982           1985
# 31           1982           2016
# 32           1925           2013
# 33           1998           2002
# 34           1961           2008
# 35           1955           2013
# 36           1865           2010
# 37      1868–1869           2019
# 38           1813           1995
# 39           1813            and
# 40           1813           2005
# 41           1891           1945
# 42           1891            and
# 43           1891           2009

# %%
# create a boolean mask that identifies rows with "and" in the "Movie Released" column
mask = df['Movie Released'].str.contains('and')

# select the rows that do not contain "and" in the "Movie Released" column
df = df[~mask]

# reset the index
df.reset_index(drop=True, inplace=True)

# display the updated DataFrame
df.head()
# Out:
#                           Title            Author Book Published  \
# 0  The Invention of Hugo Cabret    Brian Selznick           2007
# 1                My Abandonment        Peter Rock           2009
# 2                      The Help  Kathryn Stockett           2009
# 3         The Cider House Rules       John Irving           1985
# 4             David Copperfield   Charles Dickens           1850
#
#   Movie Released
# 0           2011
# 1           2018
# 2           2011
# 3           1999
# 4           2019

# %%
# Rename book publised and movie released columns so there are no spaces
df = df.rename(columns={"Book Published": "Book_Published", "Movie Released": "Movie_Released"})
df.head()
# Out:
#                           Title            Author Book_Published  \
# 0  The Invention of Hugo Cabret    Brian Selznick           2007
# 1                My Abandonment        Peter Rock           2009
# 2                      The Help  Kathryn Stockett           2009
# 3         The Cider House Rules       John Irving           1985
# 4             David Copperfield   Charles Dickens           1850
#
#   Movie_Released
# 0           2011
# 1           2018
# 2           2011
# 3           1999
# 4           2019

# %%
# Save dataframe to CSV
df.to_csv("Resources/books_to_movies.csv")
