# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 113.0.5672
# Get LATEST chromedriver version for 113.0.5672 google-chrome
# Driver [C:\Users\liz14\.wdm\drivers\chromedriver\win32\113.0.5672.63\chromedriver.exe] found in cache

# %%
url = "https://www.imdb.com/list/ls006444168/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Webscrape imdb movies from books list. 
movies_list = soup.find_all('div', class_='lister-list')

# %%
# # Webscrape imdb movies from books list. 
# movies_list = soup.find_all('div', class_='lister-list')

# # Pull movie title, year released, movie duration, genre, movie rating ("certificate"), star rating, gross amount.

# title = movies_list[0].find('h3').find('a').text

# year = movies_list[0].find('span',class_='lister-item-year').text

# movie_length = movies_list[0].find('span',class_='runtime').text

# genre = movies_list[0].find('span',class_='genre').text

# # javascript for certificate: # <span class="certificate">R</span>
# certificate = movies_list[0].find('span',class_='certificate').text

# # javascript for rating: <span class="ipl-rating-star__rating">7.5</span>
# stars = movies_list[0].find('span',class_='ipl-rating-star__rating').text

# # javascript for movie gross:
# # <span class="text-muted">Gross:</span>
# # <span name="nv" data-value="18,335,230">$18.34M</span>

# # chatGPT   
# gross = movies_list[0].find('span', string='Gross:')

# if gross:
#     gross_amount = gross.find_next_sibling('span')['data-value']
# else:
#     gross_amount = 'N/A'
    
# gross_value = gross.find_next_sibling('span')['data-value']

# #********************Discard later?
# # # find the <p> tag with class 'text_muted text-small'
# ##p_tag = soup.find('p', class_='text-muted text-small')
# #p_tag = soup.find('span', class_='text-muted').text
# #p_tag = soup.find('span', name_='nv')


# # # find the <span> tag with name 'nv' inside the <p> tag
# #span_tag = p_tag.find('span', name='nv')

# # # extract the text content of the <span> tag.
# # text = span_tag.text.strip()

# %%
certificate

# %%
# Pull movie title, year released, movie duration, genre, movie rating ("certificate"), star rating, gross amount.

# Create dictionary of lists to hold....

movies_fr_books_dict = {}
movie_title =[]
year = []
movie_length =[]
movie_genre=[]
movie_rating=[]
star_rating=[]
gross_amount=[]

def get_movietitle():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    movies_list = soup.find_all('div', class_='lister-item-content')
    
    for movie in movies_list:
        title = movie.find('h3').find('a').text
        
        movie_year = movie.find('span', class_='lister-item-year').text
        
        movie_len = movie.find('span', class_='runtime').text
        
        genre = movie.find('span', class_='genre').text.strip()
        
        try:
            certificate = movie.find('span', class_='certificate').text
        except AttributeError:
            certificate = 'N/A'
        
        stars = movie.find('span', class_='ipl-rating-star__rating').text
        
        #gross = movies_list[0].find('span', string='Gross:')
        
        gross = movie.find_all('span', string='Gross:')
        if gross:
            gross_value = gross[0].find_next_sibling('span')['data-value']
        else:
            gross_value = 'N/A'
        #gross_value = gross.find_next_sibling('span')['data-value']

        # recording values
        movie_title.append(title)
        year.append(movie_year)
        movie_length.append(movie_len)
        movie_genre.append(genre)        
        movie_rating.append(certificate)
        star_rating.append(stars)
        gross_amount.append(gross_value)

get_movietitle()

# %%
movies = []
for i in range(len(movie_title)):
    movie = {
        'title': movie_title[i],
        'year': year[i],
        'length': movie_length[i],
        'genre': movie_genre[i],
        'rating': movie_rating[i],
        'stars': star_rating[i],
        'gross': gross_amount[i]
    }
    movies.append(movie)

# print the list of dictionaries
print(movies)
# Out:
# [{'title': '127 Hours', 'year': '(2010)', 'length': '94 min', 'genre': 'Biography, Drama', 'rating': 'R', 'stars': '7.5', 'gross': '18,335,230'}, {'title': '100 Rifles', 'year': '(1969)', 'length': '110 min', 'genre': 'Adventure, Drama, War', 'rating': 'R', 'stars': '6', 'gross': 'N/A'}, {'title': 'The Hunger Games', 'year': '(2012)', 'length': '142 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': 'PG-13', 'stars': '7.2', 'gross': '408,010,692'}, {'title': 'The Hunger Games: Catching Fire', 'year': '(2013)', 'length': '146 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': 'PG-13', 'stars': '7.5', 'gross': '424,668,047'}, {'title': 'A Beautiful Mind', 'year': '(2001)', 'length': '135 min', 'genre': 'Biography, Drama', 'rating': 'PG-13', 'stars': '8.2', 'gross': '170,742,341'}, {'title': 'A Civil Action', 'year': '(1998)', 'length': '115 min', 'genre': 'Drama', 'rating': 'PG-13', 'stars': '6.6', 'gross': '56,702,901'}, {'title': 'A Clockwork Orange', 'year': '(1971)', 'length': '136 min', 'genre': 'Crime, Sci-Fi', 'rating': 'R', 'stars': '8.3', 'gross': '6,207,725'}, {'title': 'A Good Year', 'year': '(2006)', 'length': '117 min', 'genre': 'Comedy, Drama, Romance', 'rating': 'PG-13', 'stars': '6.9', 'gross': '7,458,269'}, {'title': 'A Little Romance', 'year': '(1979)', 'length': '110 min', 'genre': 'Adventure, Comedy, Romance', 'rating': 'PG', 'stars': '7.4', 'gross': 'N/A'}, {'title': 'A Room with a View', 'year': '(1985)', 'length': '117 min', 'genre': 'Drama, Romance', 'rating': 'Not Rated', 'stars': '7.2', 'gross': '20,966,644'}, {'title': 'A Walk to Remember', 'year': '(2002)', 'length': '101 min', 'genre': 'Drama, Romance', 'rating': 'PG', 'stars': '7.3', 'gross': '41,281,092'}, {'title': 'About a Boy', 'year': '(2002)', 'length': '101 min', 'genre': 'Comedy, Drama, Romance', 'rating': 'PG-13', 'stars': '7.1', 'gross': '41,385,278'}, {'title': 'All That Heaven Allows', 'year': '(1955)', 'length': '89 min', 'genre': 'Drama, Music, Romance', 'rating': 'Passed', 'stars': '7.6', 'gross': 'N/A'}, {'title': 'All the Pretty Horses', 'year': '(2000)', 'length': '116 min', 'genre': 'Drama, Romance, Western', 'rating': 'PG-13', 'stars': '5.8', 'gross': '15,527,125'}, {'title': 'Message in a Bottle', 'year': '(1999)', 'length': '126 min', 'genre': 'Drama, Romance', 'rating': 'PG-13', 'stars': '6.2', 'gross': '52,880,016'}, {'title': 'The Lucky One', 'year': '(2012)', 'length': '101 min', 'genre': 'Drama, Mystery, Romance', 'rating': 'PG-13', 'stars': '6.4', 'gross': '60,457,138'}, {'title': 'Dear John', 'year': '(I) (2010)', 'length': '108 min', 'genre': 'Drama, Mystery, Romance', 'rating': 'PG-13', 'stars': '6.3', 'gross': '80,014,842'}, {'title': 'The Last Song', 'year': '(2010)', 'length': '107 min', 'genre': 'Drama, Music, Romance', 'rating': 'PG', 'stars': '6', 'gross': '62,950,384'}, {'title': 'The Notebook', 'year': '(2004)', 'length': '123 min', 'genre': 'Drama, Romance', 'rating': 'PG-13', 'stars': '7.8', 'gross': '81,001,787'}, {'title': 'Nights in Rodanthe', 'year': '(2008)', 'length': '97 min', 'genre': 'Drama, Romance', 'rating': 'PG-13', 'stars': '6', 'gross': '41,850,659'}, {'title': 'Angels & Demons', 'year': '(2009)', 'length': '138 min', 'genre': 'Action, Mystery, Thriller', 'rating': 'PG-13', 'stars': '6.7', 'gross': '133,375,846'}, {'title': 'The Da Vinci Code', 'year': '(2006)', 'length': '149 min', 'genre': 'Mystery, Thriller', 'rating': 'PG-13', 'stars': '6.6', 'gross': '217,536,138'}, {'title': 'The Girl with the Dragon Tattoo', 'year': '(2011)', 'length': '158 min', 'genre': 'Crime, Drama, Mystery', 'rating': 'R', 'stars': '7.8', 'gross': '102,515,793'}, {'title': 'The Girl with the Dragon Tattoo', 'year': '(2009)', 'length': '152 min', 'genre': 'Crime, Drama, Mystery', 'rating': 'R', 'stars': '7.8', 'gross': '10,095,170'}, {'title': 'The Girl Who Played with Fire', 'year': '(2009)', 'length': '129 min', 'genre': 'Action, Crime, Drama', 'rating': 'R', 'stars': '7.1', 'gross': '9,081,782'}, {'title': ' ...

# %%
gross_amount
# Out:
# ['18,335,230',
#  'N/A',
#  '408,010,692',
#  '424,668,047',
#  '170,742,341',
#  '56,702,901',
#  '6,207,725',
#  '7,458,269',
#  'N/A',
#  '20,966,644',
#  '41,281,092',
#  '41,385,278',
#  'N/A',
#  '15,527,125',
#  '52,880,016',
#  '60,457,138',
#  '80,014,842',
#  '62,950,384',
#  '81,001,787',
#  '41,850,659',
#  '133,375,846',
#  '217,536,138',
#  '102,515,793',
#  '10,095,170',
#  '9,081,782',
#  '70,107,728',
#  '15,280',
#  '5,427,684',
#  '136,801,374',
#  '317,575,550',
#  '261,988,482',
#  '290,013,036',
#  '249,358,727',
#  '381,011,219',
#  '292,004,738',
#  '295,983,305',
#  '301,959,197',
#  '169,708,112',
#  '31,847,881',
#  '13,843,771',
#  '330,252,182',
#  '13,985,225',
#  '49,200,230',
#  '192,769,854',
#  '296,623,634',
#  '300,531,751',
#  '88,761,720',
#  '68,559,554',
#  '38,405,088',
#  '43,182,776',
#  'N/A',
#  '4,764,741',
#  'N/A',
#  '5,462,325',
#  'N/A',
#  'N/A',
#  '38,634,938',
#  '291,709,845',
#  '141,621,490',
#  '104,386,950',
#  '303,003,568',
#  '315,544,750',
#  '377,845,905',
#  '342,551,365',
#  '43,818,839',
#  '100,768,056',
#  '28,341,469',
#  '52,287,414',
#  '25,594,957',
#  '61,276,872',
#  '63,414,846',
#  'N/A',
#  '1,738,692',
#  '20,207,003',
#  '50,927,067',
#  '52,096,475',
#  'N/A',
#  '58,709,717',
#  '58,009,200',
#  '11,242,660',
#  '59,713,955',
#  '96,962,694',
#  '92,186,262',
#  '560,101',
#  '35,053,660',
#  '128,012,934',
#  '15,541,549',
#  '3,571,735',
#  '6,531,503',
#  '255,959,475',
#  '9,166,863',
#  '39,462,438',
#  '83,823,381',
#  '6,616,974',
#  '31,670,931',
#  '352,810',
#  '97,104,620',
#  '44,277,350',
#  '17,303,424',
#  '22,911,480']

# %%
# No longer needed; 
# movies_fr_books_dict['movie_title'] = movie_title
# movies_fr_books_dict['year'] = year
# movies_fr_books_dict['movie_length'] = movie_length
# movies_fr_books_dict['movie_genre'] = movie_genre
# movies_fr_books_dict['movie_rating'] = movie_rating
# movies_fr_books_dict['star_rating'] = star_rating
# movies_fr_books_dict['gross_amount'] = gross_value

# %%
import pandas as pd
moviesfrombooks_data = pd.DataFrame(movies)
moviesfrombooks_data.head(5)
# Out:
#                              title    year   length  \
# 0                        127 Hours  (2010)   94 min
# 1                       100 Rifles  (1969)  110 min
# 2                 The Hunger Games  (2012)  142 min
# 3  The Hunger Games: Catching Fire  (2013)  146 min
# 4                 A Beautiful Mind  (2001)  135 min
#
#                        genre rating stars        gross
# 0           Biography, Drama      R   7.5   18,335,230
# 1      Adventure, Drama, War      R     6          N/A
# 2  Action, Adventure, Sci-Fi  PG-13   7.2  408,010,692
# 3  Action, Adventure, Sci-Fi  PG-13   7.5  424,668,047
# 4           Biography, Drama  PG-13   8.2  170,742,341

# %%
#Identify datatype.
moviesfrombooks_data.dtypes
# Out:
# title     object
# year      object
# length    object
# genre     object
# rating    object
# stars     object
# gross     object
# dtype: object

# %%
# Display random sample of 10 rows from dataframe, moviesfrombooks_data

moviesfrombooks_data.sample(n=10)
# Out:
#                                     title    year   length  \
# 44            The Twilight Saga: New Moon  (2009)  130 min
# 29  Harry Potter and the Sorcerer's Stone  (2001)  152 min
# 90                           A Single Man  (2009)   99 min
# 96                         Public Enemies  (2009)  140 min
# 42                     My Sister's Keeper  (2009)  109 min
# 98                               Inkheart  (2008)  106 min
# 78                     The Lincoln Lawyer  (2011)  118 min
# 28                         The Green Mile  (1999)  189 min
# 64                       The Lovely Bones  (2009)  135 min
# 48                      Pride & Prejudice  (2005)  129 min
#
#                          genre rating stars        gross
# 44   Adventure, Drama, Fantasy  PG-13   4.7  296,623,634
# 29  Adventure, Family, Fantasy     PG   7.6  317,575,550
# 90       Crime, Drama, Romance      R   7.5    9,166,863
# 96    Action, Biography, Crime      R     7   97,104,620
# 42               Drama, Family  PG-13   7.3   49,200,230
# 98  Adventure, Family, Fantasy     PG   6.1   17,303,424
# 78       Crime, Drama, Mystery      R   7.3   58,009,200
# 28       Crime, Drama, Fantasy      R   8.6  136,801,374
# 64    Drama, Fantasy, Thriller  PG-13   6.6   43,818,839
# 48              Drama, Romance     PG   7.8   38,405,088

# %%
moviesfrombooks_data.iloc[0]['genre'].split(', ')
# Out:
# ['Biography', 'Drama']

# %%
# extract digits only from `year` column
moviesfrombooks_data['year'] = moviesfrombooks_data['year'].str.extract(r'\((\d+)\)')

# %%
# extract digits only from `movie_length` column
moviesfrombooks_data['length'] = moviesfrombooks_data['length'].str.extract(r'(\d+)\s*min')

# %%
# split genre text string into a list of genres
moviesfrombooks_data['genre'] = moviesfrombooks_data['genre'].str.split(', ')

# %%
moviesfrombooks_data = pd.get_dummies(moviesfrombooks_data, columns = ['rating'])

# %%
# pd.get_dummies(moviesfrombooks_data, columns=['movie_genre']) DOES NOT WORK

# adpated from stack overflow
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer(sparse_output=True)

moviesfrombooks_data = moviesfrombooks_data.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(moviesfrombooks_data['genre']), #.pop if you want to remove original column of list
                index=moviesfrombooks_data.index,
                columns=mlb.classes_))

# %%
moviesfrombooks_data.tail()
# Out:
#                           title  year length                         genre  \
# 95          Like Dandelion Dust  2009    100                       [Drama]
# 96               Public Enemies  2009    140    [Action, Biography, Crime]
# 97  Confessions of a Shopaholic  2009    104             [Comedy, Romance]
# 98                     Inkheart  2008    106  [Adventure, Family, Fantasy]
# 99           Revolutionary Road  2008    119              [Drama, Romance]
#
#    stars       gross  rating_N/A  rating_Not Rated  rating_PG  rating_PG-13  \
# 95     7     352,810           0                 0          0             1
# 96     7  97,104,620           0                 0          0             0
# 97   5.8  44,277,350           0                 0          1             0
# 98   6.1  17,303,424           0                 0          1             0
# 99   7.3  22,911,480           0                 0          0             0
#
#     ...  Horror  Music  Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  \
# 95  ...       0      0        0        0        0       0      0         0
# 96  ...       0      0        0        0        0       0      0         0
# 97  ...       0      0        0        0        1       0      0         0
# 98  ...       0      0        0        0        0       0      0         0
# 99  ...       0      0        0        0        1       0      0         0
#
#     War  Western
# 95    0        0
# 96    0        0
# 97    0        0
# 98    0        0
# 99    0        0
#
# [5 rows x 32 columns]

# %%
# Save/export dataframe, moviesfrombooks_data, to csv file.

moviesfrombooks_data.to_csv('Resources/CLEANEDimdb_movies_from_books.csv', index=True)

# %%
browser.quit()
